# %% [markdown]
# # Single-View Geometry (Python)
#
# ## Usage
# This code snippet provides an overall code structure and some interactive plot interfaces for the *Single-View Geometry* section of Assignment 3. In [main function](#Main-function), we outline the required functionalities step by step. Some of the functions which involves interactive plots are already provided, but [the rest](#Your-implementation) are left for you to implement.
#
# ## Package installation
# - You will need [GUI backend](https://matplotlib.org/faq/usage_faq.html#what-is-a-backend) to enable interactive plots in `matplotlib`.
# - In this code, we use `tkinter` package. Installation instruction can be found [here](https://anaconda.org/anaconda/tk).

# %% [markdown]
# # Common imports

# %%
% matplotlib tk
import matplotlib.pyplot as plt
import numpy as np

from PIL import Image
from sympy.matrices import Matrix
from sympy import Symbol
from sympy import *
from sympy import MatrixSymbol, Transpose

# %% [markdown]
# # Provided functions

# %%
def get_input_lines(im, min_lines=3):
    """
    Allows user to input line segments; computes centers and directions.
    Inputs:
        im: np.ndarray of shape (height, width, 3)
        min_lines: minimum number of lines required
    Returns:
        n: number of lines from input
        lines: np.ndarray of shape (3, n)
            where each column denotes the parameters of the line equation
        centers: np.ndarray of shape (3, n)
            where each column denotes the homogeneous coordinates of the centers
    """
    n = 0
    lines = np.zeros((3, 0))
    centers = np.zeros((3, 0))

    plt.figure()
    plt.imshow(im)
    print('Set at least %d lines to compute vanishing point' % min_lines)
    while True:
        print('Click the two endpoints, use the right key to undo, and use the middle key to stop input')
        clicked = plt.ginput(2, timeout=0, show_clicks=True)
        if not clicked or len(clicked) < 2:
            if n < min_lines:
                print('Need at least %d lines, you have %d now' % (min_lines, n))
                continue
            else:
                # Stop getting lines if number of lines is enough
                break

        # Unpack user inputs and save as homogeneous coordinates
        pt1 = np.array([clicked[0][0], clicked[0][1], 1])
        pt2 = np.array([clicked[1][0], clicked[1][1], 1])
        # Get line equation using cross product
        # Line equation: line[0] * x + line[1] * y + line[2] = 0
        line = np.cross(pt1, pt2)
        lines = np.append(lines, line.reshape((3, 1)), axis=1)
        # Get center coordinate of the line segment
        center = (pt1 + pt2) / 2
        centers = np.append(centers, center.reshape((3, 1)), axis=1)

        # Plot line segment
        plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], color='b')

        n += 1

    return n, lines, centers

# %%
def plot_lines_and_vp(im, lines, vp):
    """
    Plots user-input lines and the calculated vanishing point.
    Inputs:
        im: np.ndarray of shape (height, width, 3)
        lines: np.ndarray of shape (3, n)
            where each column denotes the parameters of the line equation
        vp: np.ndarray of shape (3, )
    """
    bx1 = min(1, vp[0] / vp[2]) - 10
    bx2 = max(im.shape[1], vp[0] / vp[2]) + 10
    by1 = min(1, vp[1] / vp[2]) - 10
    by2 = max(im.shape[0], vp[1] / vp[2]) + 10

    plt.figure()
    plt.imshow(im)
    for i in range(lines.shape[1]):
        if lines[0, i] < lines[1, i]:
            pt1 = np.cross(np.array([1, 0, -bx1]), lines[:, i])
            pt2 = np.cross(np.array([1, 0, -bx2]), lines[:, i])
        else:
            pt1 = np.cross(np.array([0, 1, -by1]), lines[:, i])
            pt2 = np.cross(np.array([0, 1, -by2]), lines[:, i])
        pt1 = pt1 / pt1[2]
        pt2 = pt2 / pt2[2]
        plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'g')

    plt.plot(vp[0] / vp[2], vp[1] / vp[2], 'ro')
    print('vanishing point is: ', (vp[0] / vp[2], vp[1] / vp[2]) )
    plt.show()

# %%
def get_top_and_bottom_coordinates(im, obj):
    """
    For a specific object, prompts user to record the top coordinate and the bottom coordinate in the image.
    Inputs:
        im: np.ndarray of shape (height, width, 3)
        obj: string, object name
    Returns:
        coord: np.ndarray of shape (3, 2)
            where coord[:, 0] is the homogeneous coordinate of the top of the object and coord[:, 1] is the homogeneous
            coordinate of the bottom
    """
    plt.figure()
    plt.imshow(im)

    print('Click on the top coordinate of %s' % obj)
    clicked = plt.ginput(1, timeout=0, show_clicks=True)
    x1, y1 = clicked[0]
    # Uncomment this line to enable a vertical line to help align the two coordinates
    # plt.plot([x1, x1], [0, im.shape[0]], 'b')
    print('Click on the bottom coordinate of %s' % obj)
    clicked = plt.ginput(1, timeout=0, show_clicks=True)
    x2, y2 = clicked[0]

    plt.plot([x1, x2], [y1, y2], 'b')

    return np.array([[x1, x2], [y1, y2], [1, 1]])

# %% [markdown]
# # Your implementation

# %%
def get_vanishing_point(lines):
    """
    Solves for the vanishing point using the user-input lines.
    """
    # <YOUR IMPLEMENTATION>
    print("lines: " + str(lines))
    lines_T = lines.T
    line_1 = lines_T[0]
    line_2 = lines_T[1]
    line_3 = lines_T[2]
    
    cross_12 = np.cross(line_1, line_2)
    cross_23 = np.cross(line_2, line_3)
    cross_13 = np.cross(line_1, line_3)
    cross_12h = cross_12 / cross_12[2]
    cross_23h = cross_23 / cross_23[2]
    cross_13h = cross_13 / cross_13[2]
    cross_sum = cross_12h + cross_23h + cross_13h
    return np.divide(cross_sum, 3)

# %%
def get_horizon_line(vpts):
    """
    Calculates the ground horizon line.
    """
    # <YOUR IMPLEMENTATION>
    p_1 = vpts[:, 0]
    p_2 = vpts[:, 1]
    
    h_line = np.cross(p_1, p_2)
    scale = np.sqrt(1 / (h_line[0] ** 2 + h_line[1] ** 2))
    h_line = h_line * scale
    
    return h_line

# %%
def plot_horizon_line(im, vpts):
    """
    Plots the horizon line.
    """
    # <YOUR IMPLEMENTATION>
    p_1, p_2 = vpts[:, 0], vpts[:, 1]
    x1, y1 = p_1[0], p_1[1]
    x2, y2 = p_2[0], p_2[1]
    plt.figure()
    plt.imshow(im)
    plt.plot([x1, x2], [y1, y2], 'ro-')
    plt.show()

# %%
def get_camera_parameters(vpts):
    """
    Computes the camera parameters. Hint: The SymPy package is suitable for this.
    """
    p_1 = Matrix(np.transpose(vpts)[0])
    p_2 = Matrix(np.transpose(vpts)[1])
    p_3 = Matrix(np.transpose(vpts)[2])
    f, u, v = Symbol('f'), Symbol('u'), Symbol('v')
    K = Matrix(((f, 0, u), (0, f, v), (0, 0, 1)))
    cons_1 = K.inv() * p_1
    cons_2 = K.inv() * p_2
    cons_3 = K.inv() * p_3
    eq_1 = cons_1.T * cons_2
    eq_2 = cons_1.T * cons_3
    eq_3 = cons_2.T * cons_3
    int_para = solve([eq_1, eq_2, eq_3], [f, u, v])
    f = np.absolute(int_para[0][0])
    u = int_para[0][1]
    v = int_para[0][2]
    return f, u, v

# %%
def get_rotation_matrix(vpts, f, u, v):
    """
    Computes the rotation matrix using the camera parameters.
    """
    calib_matrix = np.array([[f, 0, u], [0, f, v], [0, 0, 1]], dtype='float')
    Z, X, Y = vpts[:, 0], vpts[:, 1], vpts[:, 2]
    
    r1 = np.matmul(np.linalg.inv(calib_matrix), X)
    r2 = np.matmul(np.linalg.inv(calib_matrix), Y)
    r3 = np.matmul(np.linalg.inv(calib_matrix), Z)
    
    r1 = r1 / np.linalg.norm(r1)
    r2 = r2 / np.linalg.norm(r2)
    r3 = r3 / np.linalg.norm(r3)
    
    R_matrix = np.column_stack((r1, r2, r3))
    return R_matrix

# %%
def estimate_height(im, vpts, ref_coords, obj_coords, ref_height):
    """
    Estimates height for a specific object using the recorded coordinates. You might need to plot additional images here for
    your report.
    """
    
    vx, vy, vz = vpts[:, 0], vpts[:, 1], vpts[:, 2]
    r, b = obj_coords[:, 0], obj_coords[:, 1]
    t_0, b_0 = ref_coords[:, 0], ref_coords[:, 1]
    
    v = np.cross(np.cross(b, b_0), np.cross(vx, vy))
    v = v / v[-1]
    t = np.cross(np.cross(v, t_0), np.cross(r, b))
    t = t / t[-1]
    height = ref_height / ((np.linalg.norm(t - b) * np.linalg.norm(vz - r)) / (np.linalg.norm(r - b) * np.linalg.norm(vz - t)))
    
    plt.figure()
    plt.imshow(im)
    plt.plot([r[0], b[0]], [r[1], b[1]], 'b', marker = ",")
    plt.plot([vx[0], vy[0]], [vx[1], vy[1]], 'r', marker = ",")
    plt.plot([b[0], v[0]], [b[1], v[1]], 'r', marker = ",")
    plt.plot([t[0], v[0]], [t[1], v[1]], 'r', marker = ",")
    plt.plot([b_0[0], v[0]], [b_0[1], v[1]], 'r', marker = ",")
    plt.plot([t_0[0], v[0]], [t_0[1], v[1]], 'r', marker = ",")
    plt.plot([t_0[0], b_0[0]], [t_0[1], b_0[1]], 'b', marker = ",")
    plt.show()
    
    return height

# %% [markdown]
# # Main function

# %%
im = np.asarray(Image.open('CSL.jpg'))

# Part 1
# Get vanishing points for each of the directions
num_vpts = 3
vpts = np.zeros((3, num_vpts))
for i in range(num_vpts):
    print('Getting vanishing point %d' % i)
    # Get at least three lines from user input
    n, lines, centers = get_input_lines(im)
    # <YOUR IMPLEMENTATION> Solve for vanishing point
    vpts[:, i] = get_vanishing_point(lines)
    # Plot the lines and the vanishing point
    plot_lines_and_vp(im, lines, vpts[:, i])

# <YOUR IMPLEMENTATION> Get the ground horizon line
horizon_line = get_horizon_line(vpts)
print('h_line is:', horizon_line)
# <YOUR IMPLEMENTATION> Plot the ground horizon line
plot_horizon_line(im, vpts)

# Part 2
# <YOUR IMPLEMENTATION> Solve for the camera parameters (f, u, v)
f, u, v = get_camera_parameters(vpts)
print('camera para:', f,u,v)

# Part 3
# <YOUR IMPLEMENTATION> Solve for the rotation matrix
R = get_rotation_matrix(vpts, f, u, v)
print('R_Matrix:',R)

# Part 4
# Record image coordinates for each object and store in map
objects = ('person', 'CSL building', 'the spike statue', 'the lamp posts')
coords = dict()
for obj in objects:
    coords[obj] = get_top_and_bottom_coordinates(im, obj)

# <YOUR IMPLEMENTATION> Estimate heights
for obj in objects[1:]:
    print('Estimating height of %s' % obj)
    height = estimate_height(im, vpts, coords['person'], coords[obj], 1.67)
    print(height)

objects = ('person', 'CSL building', 'the spike statue', 'the lamp posts')
coords = dict()
for obj in objects:
    coords[obj] = get_top_and_bottom_coordinates(im, obj)

# <YOUR IMPLEMENTATION> Estimate heights
for obj in objects[1:]:
    print('Estimating height of %s' % obj)
    height = estimate_height(im, vpts, coords['person'], coords[obj], 1.82)
    print(height)
# Out:
# Getting vanishing point 0
# Set at least 3 lines to compute vanishing point
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# lines: [[-2.47741935e+01 -6.19354839e+00  0.00000000e+00]
#  [ 1.23870968e+02  1.21806452e+02  1.23870968e+02]
#  [ 4.16725911e+03 -1.85400275e+04 -3.04978314e+04]]
# vanishing point is:  (1497.9685565330747, 235.9933528836756)
# Getting vanishing point 1
# Set at least 3 lines to compute vanishing point
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# Click the two endpoints, use the right key to undo, and use the middle key to stop input
# ...
